# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("C:/Diwali_Sales_Data.csv", encoding= "latin1")
print (df.head())
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
print (df.shape)
# Out:
# (11251, 15)

# %%
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB
# ...

# %%
print (df.describe())
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
print (df.isnull().sum())
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %% [markdown]
# Deleting Extra columns

# %%
df.drop(["unnamed1","Status"] , axis = 1, inplace = True)

# %%
print (df.shape)
# Out:
# (11251, 13)

# %% [markdown]
# Removing Null values from columns

# %%
print (df.dropna(axis = 0 , inplace = True))
# Out:
# None

# %%
print (df.shape)
# Out:
# (11239, 13)

# %%
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.2+ MB
# None

# %%
df['Amount']= df["Amount"].astype("int")
df["Amount"].dtypes
# Out:
# dtype('int64')

# %%
df["User_ID"]= df['User_ID'].astype("int")
df['User_ID'].dtypes
# Out:
# dtype('int64')

# %%
df.rename(columns={"Marital_status" : "Shaadi"}, inplace=True)

# %%
print (df.columns)
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  int64
# dtypes: int64(5), object(8)
# memory usage: 1.2+ MB
# None

# %%
print (df.head())
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  Amount
# 0     Maharashtra   Western       Healthcare             Auto       1   23952
# 1  Andhra Pradesh  Southern             Govt             Auto       3   23934
# 2   Uttar Pradesh   Central       Automobile             Auto       3   23924
# 3       Karnataka  Southern     Construction             Auto       2   23912
# 4         Gujarat   Western  Food Processing             Auto       2   23877

# %% [markdown]
# Exploratory Data Analysis

# %%
print (df.columns)
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %% [markdown]
# On the basis of GENDER

# %%
ax = sns.countplot(x = "Gender", data = df)
plt.title("Gender Comparison")
for bar in ax.containers:
    ax.bar_label(bar)

# %%
sales_by_gender = df.groupby(["Gender"], as_index=False)["Amount"].sum()
print (sales_by_gender)
# Out:
#   Gender       Amount
# 0      F  74335856.43
# 1      M  31913276.00

# %%
ax = sns.barplot(x = "Gender", y = "Amount" , data = sales_by_gender)
for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# From the above analysis we can say that Female has higher purchase power than female and has done more shopping in Diwali

# %%
ax = sns.countplot(x = "Age Group" , data = df , hue = "Gender")
plt.title("Age Comparison")
for bar in ax.containers:
    ax.bar_label(bar)
plt.show()

# %%
sales_by_age = df.groupby(["Age Group"] , as_index= False)["Amount"].sum().sort_values(by = "Amount",ascending=False)
print (sales_by_age)
# Out:
#   Age Group       Amount
# 2     26-35  42613443.94
# 3     36-45  22144995.49
# 1     18-25  17240732.00
# 4     46-50   9207844.00
# 5     51-55   8261477.00
# 6       55+   4080987.00
# 0      0-17   2699653.00

# %%
ax = sns.barplot(x = "Age Group", y = "Amount" , data = sales_by_age)

# %% [markdown]
# From the above analysis we can say that the highest numbers of buyers are woman and from the age group 26-35

# %%
print (df.columns)
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
ax = sns.countplot(x = "State", data = df)
sns.set(rc={"figure.figsize" : (20,5)})
for bar in ax.containers:
    ax.bar_label(bar)

# %%
sales_by_state = df.groupby(["State"], as_index=False)['Orders'].sum().sort_values(by ="Orders", ascending=False).head(10)
ax = sns.barplot(x = "State", y ="Orders" , data = sales_by_state )
for bar in ax.containers:
    ax.bar_label(bar)

# %%
sales_by_state = df.groupby(["State"], as_index=False)['Amount'].sum().sort_values(by ="Amount", ascending=False).head(10)
ax = sns.barplot(x = "State", y ="Amount" , data = sales_by_state )
for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# From the above anlaysis we can say that the maximum orders and revenue are from uttar pradesh and lowest ordes and revenue are from Gujrat from the top 10 states

# %% [markdown]
# Marital Status

# %%
print (df.columns)
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
ax = sns.countplot(x = "Marital_Status", data = df , hue = "Gender")
for bar in ax.containers:
    ax.bar_label(bar)

# %%
sales_by_maritalStatus = df.groupby(['Marital_Status' , 'Gender'], as_index=False)["Amount"].sum().sort_values(by="Amount" , ascending=False)
print (sales_by_maritalStatus)
# Out:
#    Marital_Status Gender       Amount
# 0               0      F  43786648.44
# 2               1      F  30549207.99
# 1               0      M  18338738.00
# 3               1      M  13574538.00

# %%
sns.barplot(x = "Marital_Status", y= "Amount", data = sales_by_maritalStatus , hue= "Gender")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# From the above analysis we can say that highest number of shoppers in the diwali are unmarried woman

# %% [markdown]
# Occupation

# %%
print(df.columns)
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
ax = sns.countplot(x = "Occupation", data = df , hue = "Gender")
for bar in ax.containers:
    ax.bar_label(bar)

# %%
sales_by_occupaton = df.groupby(["Occupation" , "Gender"], as_index=False)["Amount"].sum().sort_values(by = "Amount", ascending=False).head(10)
print (sales_by_occupaton)
# Out:
#      Occupation Gender       Amount
# 20    IT Sector      F  10184835.00
# 4      Aviation      F   9007393.00
# 16   Healthcare      F   8968232.49
# 6       Banking      F   7792295.95
# 14         Govt      F   6002907.00
# 21    IT Sector      M   4570244.00
# 24        Media      F   4375029.99
# 18  Hospitality      F   4183199.00
# 17   Healthcare      M   4066355.00
# 2    Automobile      F   3768843.00

# %%
ax = sns.barplot(x = "Occupation" , y="Amount" , data = sales_by_occupaton, hue="Gender")
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# From the above analysis we can day that the most amount spend by the female in IT sector.

# %% [markdown]
# Product Category

# %%
print (df.columns)
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
ax = sns.countplot(x = "Product_Category" , data = df)
for bar in ax.containers:
    ax.bar_label(bar)

# %%
sales_by_ProductCategory = df.groupby(["Product_Category"], as_index=False)["Amount"].sum().sort_values(by="Amount").head(10)

# %%
ax = sns.barplot(x = "Product_Category", y = "Amount", data = sales_by_ProductCategory )
for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# From the above analysis we can say that the people have purchased maximum automobile and minimum is office items in the Diwali
